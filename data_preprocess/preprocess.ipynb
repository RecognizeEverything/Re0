# %%
import os
import shutil

# %%
source_root = "/media/user/Expansion/jwb_own/scannet_V2/scans/"
symlink_root = "/media/user/Expansion/Re0/data640/"
for scene_name in os.listdir('/media/user/Expansion/Re0/data640/'):
    if scene_name=='intrinsics.txt':
        continue
    scene_name='scene0000_00'
    source_ply = os.path.join('/media/user/Expansion/jwb_own/scannet_V2/scans',scene_name, scene_name+'_vh_clean_2.ply')
    symlink_ply = os.path.join(symlink_root,scene_name, scene_name+'_vh_clean_2.ply')
    shutil.copy(source_ply, symlink_ply)
    #os.symlink(source_ply, symlink_ply)
    print(symlink_ply)
# Out:
# /media/user/Expansion/Re0/data640/scene0000_00/scene0000_00_vh_clean_2.ply
# /media/user/Expansion/Re0/data640/scene0000_00/scene0000_00_vh_clean_2.ply
# /media/user/Expansion/Re0/data640/scene0000_00/scene0000_00_vh_clean_2.ply
# /media/user/Expansion/Re0/data640/scene0000_00/scene0000_00_vh_clean_2.ply
# /media/user/Expansion/Re0/data640/scene0000_00/scene0000_00_vh_clean_2.ply
# /media/user/Expansion/Re0/data640/scene0000_00/scene0000_00_vh_clean_2.ply
# /media/user/Expansion/Re0/data640/scene0000_00/scene0000_00_vh_clean_2.ply
# /media/user/Expansion/Re0/data640/scene0000_00/scene0000_00_vh_clean_2.ply
# /media/user/Expansion/Re0/data640/scene0000_00/scene0000_00_vh_clean_2.ply
# /media/user/Expansion/Re0/data640/scene0000_00/scene0000_00_vh_clean_2.ply
# /media/user/Expansion/Re0/data640/scene0000_00/scene0000_00_vh_clean_2.ply
# /media/user/Expansion/Re0/data640/scene0000_00/scene0000_00_vh_clean_2.ply
# ...
